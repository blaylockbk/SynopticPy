# %% [markdown]
# # Latest
#
# Demonstrate `synoptic.services.Latest`

# %%
from synoptic import Latest

import matplotlib.pyplot as plt

# %%
df = Latest(
    bbox=[-120, 40, -119, 41],
    showemptystations=True,
    vars="air_temp",
    units="english",
).df()
df
# Out:
# 🚚💨 Speedy delivery from Synoptic latest service.
# 📦 Received data from 12 stations.
# shape: (12, 20)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ date_time ┆ variable ┆ sensor_in ┆ is_derive ┆ … ┆ period_of ┆ period_of ┆ is_restri ┆ is_active │
# │ ---       ┆ ---      ┆ dex       ┆ d         ┆   ┆ _record_s ┆ _record_e ┆ cted      ┆ ---       │
# │ datetime[ ┆ str      ┆ ---       ┆ ---       ┆   ┆ tart      ┆ nd        ┆ ---       ┆ bool      │
# │ μs, UTC]  ┆          ┆ u32       ┆ bool      ┆   ┆ ---       ┆ ---       ┆ bool      ┆           │
# │           ┆          ┆           ┆           ┆   ┆ datetime[ ┆ datetime[ ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆ μs, UTC]  ┆ μs, UTC]  ┆           ┆           │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 1998-07-2 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 8         ┆ 0         ┆           ┆           │
# │ 06:37:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 05:37:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 1998-07-2 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 8         ┆ 0         ┆           ┆           │
# │ 06:59:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 05:59:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ null      ┆ null     ┆ null      ┆ null      ┆ … ┆ 2008-11-0 ┆ 2012-11-2 ┆ false     ┆ false     │
# │           ┆          ┆           ┆           ┆   ┆ 5         ┆ 2         ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 12:44:00  ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2013-01-0 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 4         ┆ 0         ┆           ┆           │
# │ 07:00:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 05:22:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2013-01-0 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 4         ┆ 0         ┆           ┆           │
# │ 06:36:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 06:12:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2013-01-0 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 4         ┆ 0         ┆           ┆           │
# │ 06:28:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 04:26:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2023-12-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2013-12-1 ┆ 2024-01-0 ┆ false     ┆ false     │
# │ 8         ┆          ┆           ┆           ┆   ┆ 9         ┆ 1         ┆           ┆           │
# │ 20:20:00  ┆          ┆           ┆           ┆   ┆ 00:00:00  ┆ 07:20:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ null      ┆ null     ┆ null      ┆ null      ┆ … ┆ 2016-07-1 ┆ 2019-05-1 ┆ false     ┆ false     │
# │           ┆          ┆           ┆           ┆   ┆ 8         ┆ 7         ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆ 18:18:00  ┆ 16:00:00  ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2017-02-1 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 2         ┆ 0         ┆           ┆           │
# │ 07:00:00  ┆          ┆           ┆           ┆   ┆ 08:19:00  ┆ 06:00:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# │ 2024-11-1 ┆ air_temp ┆ 1         ┆ false     ┆ … ┆ 2023-01-0 ┆ 2024-11-1 ┆ false     ┆ true      │
# │ 0         ┆          ┆           ┆           ┆   ┆ 3         ┆ 0         ┆           ┆           │
# │ 07:00:00  ┆          ┆           ┆           ┆   ┆ 22:09:00  ┆ 06:15:00  ┆           ┆           │
# │ UTC       ┆          ┆           ┆           ┆   ┆ UTC       ┆ UTC       ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

for i in df.iter_rows(named=True):
    ax.text(
        i["longitude"],
        i["latitude"] + 0.01,
        f'{i["stid"]}\n{i["value"]} F',
        va="bottom",
        ha="left",
    )
    if i["value"] is None:
        art = ax.scatter(
            i["longitude"],
            i["latitude"],
            color=None,
            ec="k",
            s=100,
        )
    else:
        art = ax.scatter(
            i["longitude"],
            i["latitude"],
            c=i["value"],
            ec="k",
            cmap="Spectral_r",
            vmin=20,
            vmax=80,
            s=100,
        )
plt.colorbar(art, ax=ax, location="bottom", pad=0.05, label="Air Temperature (F)")

# %% [markdown]
# Whoa, there is a station reporting 118 degree F and another reporting 18 F.
