# %% [markdown]
# **Brian Blaylock**
#
# # Plot Timeseries

# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append('../')

from get_Synoptic import stations_timeseries

from plot_Synoptic import *

# %%
params = dict(stid='wbb,kmry,ukbkb,qhw,psrim,psink',
              vars='air_temp,relative_humidity,ozone_concentration,wind_speed,wind_direction',
              units='English',
              recent=3200, verbose='HIDE')
plot_timeseries(**params)
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [timeseries]: https://api.synopticdata.com/v2/stations/timeseries?stid=wbb,kmry,ukbkb,qhw,psrim,psink&vars=air_temp,relative_humidity,ozone_concentration,wind_speed,wind_direction&units=English&recent=3200&token=🙈HIDDEN
#
# Returned [6] stations. ['WBB', 'KMRY', 'QHW', 'PSINK', 'PSRIM', 'UKBKB']

# %% [markdown]
# ## Plot the map of the station locations

# %%
fig, ax = plt.subplots(1,1, figsize=[5,5],
                       subplot_kw=dict(projection=ccrs.LambertConformal()))

params = dict(radius='ANIC1,50', network='96,2', recent=120, vars='wind_speed')
map_timeseries(ax=ax, verbose='HIDE', **params)
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [timeseries]: https://api.synopticdata.com/v2/stations/timeseries?radius=ANIC1,50&network=96,2&recent=120&vars=wind_speed&token=🙈HIDDEN
#
# Returned [26] stations. ['CEEC1', 'DLVC1', 'LCBC1', 'LPOC1', 'MBUC1', 'MTIC1', 'ROVC1', 'SBIC1', 'SNCC1', 'SRIC1', 'WLYC1', 'TCLC1', 'OZNC1', 'CSVC1', 'ANIC1', 'MBCC1', '46025', '46053', 'TPGC1', 'MOIC1', 'SBVC1', 'MPWC1', 'CXPC1', 'HRMC1', 'MLXC1', 'PHCC1']

# %%
fig, ax = plt.subplots(1,1, figsize=[5,5],
                       subplot_kw=dict(projection=ccrs.LambertConformal()))

params = dict(radius='UKBKB,10', recent=120, vars='wind_speed')
map_timeseries(ax=ax, verbose='HIDE', **params)
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [timeseries]: https://api.synopticdata.com/v2/stations/timeseries?radius=UKBKB,10&recent=120&vars=wind_speed&token=🙈HIDDEN
#
# Returned [10] stations. ['KPVU', 'QSF', 'C9348', 'FG006', 'FG012', 'D5744', 'UKBKB', 'UTPRV', 'UTBRC', 'BSEU1']
