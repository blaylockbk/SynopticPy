# %% [markdown]
# **Brian Blaylock**
# **August 25, 2020**
#
# # 📃 Example: `networks`, `networktypes`, `variables`, `qctypes`
# ## Get lists of the Synoptic API internal names

# %%
import sys

# Need to tell Python where to find `synoptic`. 
# This says to look back one directory (relative to this notebook).
sys.path.append('../')

from synoptic.services import networks, networktypes, variables, qctypes

# %% [markdown]
# ## `networks`
# For a list of available network providers, use the `networks` service.
#
# These are also listed in the API docs: https://developers.synopticdata.com/about/station-providers/

# %%
networks(verbose='HIDE')
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [networks]: https://api.synopticdata.com/v2/networks?token=🙈HIDDEN
#      CATEGORY  REPORTING_STATIONS  \
# ID
# 1           7                2482
# 2           9                2313
# 3           4                  27
# 4          10                 135
# 5           4                  33
# ...       ...                 ...
# 261         6                  30
# 262         7               11538
# 263         6                  10
# 3020        1                  11
# 264         6                   3
#
#                                        PERIOD_OF_RECORD  \
# ID
# 1     {'start': '1997-01-01T00:00:00Z', 'end': '2020...
# 2     {'start': '1997-01-03T00:00:00Z', 'end': '2007...
# 3     {'start': '1999-01-05T00:00:00Z', 'end': '2020...
# 4     {'start': '1997-04-01T00:00:00Z', 'end': '2019...
# 5     {'start': '1997-04-01T00:00:00Z', 'end': '2014...
# ...                                                 ...
# ...

# %% [markdown]
# ## `networktypes`
# For a list of network types, use `networktypes`
#
# These are also listed in the API docs: https://developers.synopticdata.com/about/station-network-type/

# %%
networktypes(verbose='HIDE')
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [networktypes]: https://api.synopticdata.com/v2/networktypes?token=🙈HIDDEN
#                                      PERIOD_OF_RECORD  \
# ID
# 1   {'start': '1997-01-01T00:00:00Z', 'end': '2020...
# 2   {'start': '1997-01-03T00:00:00Z', 'end': '2007...
# 3   {'start': '1999-01-05T00:00:00Z', 'end': '2020...
# 4   {'start': '1997-04-01T00:00:00Z', 'end': '2019...
# 5   {'start': '1997-04-01T00:00:00Z', 'end': '2014...
# 6   {'start': '1998-01-27T00:00:00Z', 'end': '2004...
# 7   {'start': '1997-04-03T00:00:00Z', 'end': '2002...
# 8   {'start': '1997-09-11T00:00:00Z', 'end': '2020...
# 9   {'start': '1999-11-01T00:00:00Z', 'end': '2005...
# 10  {'start': '1997-10-31T00:00:00Z', 'end': '2020...
# 11  {'start': '1997-10-22T00:00:00Z', 'end': '2002...
# 12  {'start': '1998-01-01T00:00:00Z', 'end': '2005...
# 13  {'start': '1998-01-01T00:00:00Z', 'end': '2020...
#
#                    DESCRIPTION        NAME
# ID
# ...

# %% [markdown]
# ## `variables`
# For a list of available variables, use `variables`.
#
# These are also listed in the API docs: https://developers.synopticdata.com/about/station-variables/

# %%
variables(verbose='HIDE')
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [variables]: https://api.synopticdata.com/v2/variables?token=🙈HIDDEN
#                                        long_name     unit vid
# air_temp                             Temperature  Celsius   3
# dew_point_temperature                  Dew Point  Celsius   4
# relative_humidity              Relative Humidity        %   5
# wind_speed                            Wind Speed      m/s   6
# wind_direction                    Wind Direction  Degrees   7
# ...                                          ...      ...  ..
# wind_cardinal_direction  Wind cardinal direction            0
# weather_summary                  Weather summary            0
# heat_index                            Heat index            0
# wet_bulb_temperature        Wet bulb temperature            0
# weather_condition              Weather condition            0
#
# [144 rows x 3 columns]

# %% [markdown]
# ## `qctypes`
# For a list of Quality Control types, use `qctypes`.
#
# This is also listed on the API docs: https://developers.synopticdata.com/about/qc/types/

# %%
qctypes()
# Out:
#  🚚💨 Speedy Delivery from Synoptic API [qctypes]: https://api.synopticdata.com/v2/qctypes?token=0bbe0e9fda7945a68951cc1bdebb2b0d
#      SOURCE_ID                      SHORTNAME  \
# ID
# 1            1                 sl_range_check
# 3            1                  sl_pers_check
# 10           1       sl_windspd_maxgust_check
# 12           1       sl_windspd_winddir_check
# 13           2                 ma_range_check
# ..         ...                            ...
# 101          1  sl_percentile_hioutlier_check
# 102          1     sl_percentile_loflag_check
# 103          1  sl_percentile_looutlier_check
# 104          1    sl_spatial_percentile_check
# 105          1         sl_spatial_value_check
#
#                                            NAME
# ID
# 1                      SynopticLabs Range Check
# 3       SynopticLabs Temporal Persistence Check
# 10    SynopticLabs Wind Speed vs. Maximum Gusts
# 12   SynopticLabs Wind Speed vs. Wind Direction
# ...
